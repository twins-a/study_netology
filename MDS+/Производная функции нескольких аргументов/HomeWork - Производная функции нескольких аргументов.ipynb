# %% [markdown]
# ## Домашнее задание
#
# 1. Вычислить вектор градиента и матрицу Гессе для функции: f(X) = 2x1^3-3x1x2+2x2x3^2-x2^3
#
# В точке M=(2,1,1).
#
# 2. Постройте трехмерный график функции: f(X)=x2^2-x1^2x2+2x1x2 => f(X)=y^2-x^2y+2xy
#
#
# А также график линий уровня с уровнями {1,5,10}

# %% [markdown]
# ### Вычислю вектор градиента и матрицу Гессе для функции: f(X) = 2x1^3-3x1x2+2x2x3^2-x2^3
#
# # f(X) = 2*x1^3-3*x1*x2+2*x2*x3^2-x2^3
# В точке M=(2,1,1).
#
#
# Градиент это вектор частных производных

# %%
import sympy as sym

# %%
x1=sym.Symbol('x1')
x2=sym.Symbol('x2')
x3=sym.Symbol('x3')

# %%
2*x1**3-3*x1*x2+2*x2*x3**2-x2**3
# Out:
# 2*x1**3 - 3*x1*x2 - x2**3 + 2*x2*x3**2

# %%
fun=2*x1**3-3*x1*x2+2*x2*x3**2-x2**3

# %%
# частная производная по x1
sym.diff(fun, x1)
# Out:
# 6*x1**2 - 3*x2

# %%
# частная производная по x2
sym.diff(fun, x2)
# Out:
# -3*x1 - 3*x2**2 + 2*x3**2

# %%
# частная производная по x3
sym.diff(fun, x3)
# Out:
# 4*x2*x3

# %%
grad_t = np.array([['6*x1**2 - 3*x2'], ['-3*x1 - 3*x2**2 + 2*x3**2'], ['4*x2*x3']])
grad_t
# Out:
# array([['6*x1**2 - 3*x2'],
#        ['-3*x1 - 3*x2**2 + 2*x3**2'],
#        ['4*x2*x3']], dtype='<U25')

# %%
# Подставляю (2,1,1). 
# Получаю: 21, -7, 4
# Ответ: вектор градиента =
grad = np.array([[21], [-7], [4]])
grad
# Out:
# array([[21],
#        [-7],
#        [ 4]])

# %% [markdown]
# ### Теперь вычислю Матрица Гессе
#
# ## Матрица Гессе это квадратная симметричная матрица вторых производных

# %%
p1=sym.diff(fun, x1)
p2=sym.diff(fun, x2)
p3=sym.diff(fun, x3)
print(f'Частн. произв по x1 = {p1} \nЧастн. произв по x2 = {p2} \nЧастн. произв по x3 = {p3}')
# Out:
# Частн. произв по x1 = 6*x1**2 - 3*x2
# Частн. произв по x2 = -3*x1 - 3*x2**2 + 2*x3**2
# Частн. произв по x3 = 4*x2*x3

# %%
# градиент равен:
grad_t = np.array([['6*x1**2 - 3*x2'], ['-3*x1 - 3*x2**2 + 2*x3**2'], ['4*x2*x3']])
grad_t
# Out:
# array([['6*x1**2 - 3*x2'],
#        ['-3*x1 - 3*x2**2 + 2*x3**2'],
#        ['4*x2*x3']], dtype='<U25')

# %%
# Вычисляю вторые производные:
# сначала для диагонали:
zn11=sym.diff(6*x1**2 - 3*x2, x1)
zn22=sym.diff(-3*x1 - 3*x2**2 + 2*x3**2, x2)
zn33=sym.diff(4*x2*x3, x3)
print(f'Частн. произв по x1 = {dia1} \nЧастн. произв по x2 = {dia2} \nЧастн. произв по x3 = {dia3}')
# Out:
# Частн. произв по x1 = 12*x1
# Частн. произв по x2 = -6*x2
# Частн. произв по x3 = 4*x2

# %%
# теперь остальные элементы матрицы 3*3
zn12=sym.diff(-3*x1 - 3*x2**2 + 2*x3**2, x1)
zn12
# Out:
# -3

# %%
zn13=sym.diff(4*x2*x3, x1)
zn13
# Out:
# 0

# %%
zn21=sym.diff(6*x1**2 - 3*x2, x2)
zn21
# Out:
# -3

# %%
zn23=sym.diff(4*x2*x3, x2)
zn23
# Out:
# 4*x3

# %%
zn31=sym.diff(6*x1**2 - 3*x2, x3)
zn31
# Out:
# 0

# %%
zn32=sym.diff(4*x2*x3, x2)
zn32
# Out:
# 4*x3

# %%
# Собираю все в кучу:
mat_g = np.array([[zn11, zn12, zn13],
                  [zn21, zn22, zn23],
                  [zn31, zn32, zn33],
                  ])
print(mat_g)
# Out:
# [[12*x1 -3 0]
#  [-3 -6*x2 4*x3]
#  [0 4*x3 4*x2]]

# %% [markdown]
# ### Подставляю значения (2,1,1) и получаю:

# %%
# Собираю все в кучу:
mat_g1 = np.array([[24, -3, 0],
                  [-3, -6, 4],
                  [0, 4, 4],
                  ])
print(mat_g1)
# Out:
# [[24 -3  0]
#  [-3 -6  4]
#  [ 0  4  4]]

# %% [markdown]
# ### Построю трехмерный график функции: f(X)=x2^2-x1^2x2+2x1x2 => f(X)=y^2-x^2y+2xy

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

x = np.arange(-5, 15, 0.025)
y = np.arange(-5, 15, 0.025)
X,Y = np.meshgrid(x,y)
Z = Y**2-X**2*Y+2*X*Y

surf = ax.plot_surface(X, Y, Z, cmap='viridis', linewidth=0, antialiased=False)
# surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)

#ax.set_zlim(-550, 550)
ax.zaxis.set_major_locator(LinearLocator(10))
#ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

#fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_title('Learning about 3D plots')



plt.show()

# %%
# Здесь все то же самое, только дополнительно задаю азимут, расстояние и уровень для просмотра
fig = plt.figure()
ax = fig.gca(projection='3d')

x = np.arange(-5, 15, 0.025)
y = np.arange(-5, 15, 0.025)
X,Y = np.meshgrid(x,y)
Z = Y**2-X**2*Y+2*X*Y

surf = ax.plot_surface(X, Y, Z, cmap='viridis', linewidth=0, antialiased=False)
# surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)

#ax.set_zlim(-550, 550)
ax.zaxis.set_major_locator(LinearLocator(10))
#ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

#fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_title('Learning about 3D plots')

ax.asim=5 # азимут
ax.dist=5 # расстояние
ax.elev=15 # уровень

plt.show()

# %% [markdown]
# ### Теперь график линий уровня с уровнями {1,5,10}

# %%
# from mpl_toolkits.mplot3d import Axes3D
# from matplotlib import cm
# from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %%
x = np.arange(-4, 4, 0.025)
y = np.arange(-5, 5, 0.025)
X,Y = np.meshgrid(x,y)
Z = Y**2-X**2*Y+2*X*Y

fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, [1,5,10])
ax.clabel(CS, inline=True, fontsize=8)
# Out:
# <a list of 6 text.Text objects>
